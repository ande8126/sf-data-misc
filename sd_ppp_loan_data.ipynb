# %%
import pandas as pd

# %%
ppp_loans = pd.read_csv(r"C:\Users\panderson\OneDrive - Gannett Company, Incorporated\Documents\notes_07062020sdppploans.csv")

# %%
ppp_loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1944 entries, 0 to 1943
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   LoanRange      1944 non-null   object
#  1   BusinessName   1944 non-null   object
#  2   Address        1944 non-null   object
#  3   City           1944 non-null   object
#  4   State          1944 non-null   object
#  5   Zip            1944 non-null   int64
#  6   NAICSCode      1944 non-null   int64
#  7   BusinessType   1942 non-null   object
#  8   RaceEthnicity  1944 non-null   object
#  9   Gender         1944 non-null   object
#  10  Veteran        1944 non-null   object
#  11  NonProfit      173 non-null    object
#  12  JobsRetained   1750 non-null   float64
#  13  DateApproved   1944 non-null   int64
#  14  Lender         1944 non-null   object
#  15  CD             1944 non-null   object
# dtypes: float64(1), int64(3), object(12)
# memory usage: 151.9+ KB

# %%
ppp_loans.head()
# Out:
#             LoanRange            BusinessName                Address  \
# 0  e $150,000-350,000  101 TECHNOLOGIES, INC.         1616 E 10TH ST
# 1      b $2-5 million     16 HOTEL PROPERTIES        2011 8TH AVE NE
# 2  e $150,000-350,000         25TH AVE L.L.C.             910 4TH ST
# 3  e $150,000-350,000  281 TRAVEL CENTER INC.  601 Commerical Ave SW
# 4  e $150,000-350,000             3 NORTH LLC        14515 485th Ave
#
#              City State    Zip  NAICSCode                     BusinessType  \
# 0     SIOUX FALLS    SD  57103     541519                      Corporation
# 1        ABERDEEN    SD  57401     721110              Sole Proprietorship
# 2       BROOKINGS    SD  57006     721110  Limited  Liability Company(LLC)
# 3          WOLSEY    SD  57384     447110                      Corporation
# 4  BIG STONE CITY    SD  57216     238110  Limited  Liability Company(LLC)
#
#   RaceEthnicity      Gender      Veteran NonProfit  JobsRetained  \
# ...

# %%
sf_ppp = ppp_loans[ppp_loans.City.str.contains('sioux falls', case = False)]

# %%
sf_ppp.head()
# Out:
#                LoanRange                   BusinessName  \
# 0     e $150,000-350,000         101 TECHNOLOGIES, INC.
# 6     e $150,000-350,000              3D SECURITY, INC.
# 8     e $150,000-350,000                       44I, INC
# 9     e $150,000-350,000            605 COMPANIES, INC.
# 10  d $350,000-1 million  69TH STREET LOOK'S MARKET LLC
#
#                           Address         City State    Zip  NAICSCode  \
# 0                  1616 E 10TH ST  SIOUX FALLS    SD  57103     541519
# 6   47185 WILD CLOVER CIR Ste 200  SIOUX FALLS    SD  57107     423990
# 8              1602 S WESTERN AVE  SIOUX FALLS    SD  57105     541810
# 9                 700 e 65th st n  SIOUX FALLS    SD  57104     236115
# 10                 500 E 69th St.  SIOUX FALLS    SD  57108     722511
#
#                        BusinessType RaceEthnicity      Gender      Veteran  \
# 0                       Corporation         White  Male Owned   Unanswered
# ...

# %%
sfloans = sf_ppp.groupby("LoanRange").LoanRange.count()

# %%
sfloans.head()
# Out:
# LoanRange
# a $5-10 million           2
# b $2-5 million           33
# c $1-2 million           62
# d $350,000-1 million    202
# e $150,000-350,000      343
# Name: LoanRange, dtype: int64
